# %% [markdown]
# [link text](https://)# **Project Name**- Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
#  This EDA project on Hotel Booking Analysis investigates cancellations, and their underlying patterns; and suggests measures that can be implemented to reduce cancellations and secure revenue:
#  The project covers booking information for a city hotel and a resort hotel including information such as when the booking was made, lenth of stay, the number of adults,children.The project went through the basic idea of EDA and visualization process.
#  In this project I will do Exploratory Data Analysis on the give dataset.The project sugguests measures that can be implemented to reduce cancellations and secure revenue.For example,hotels can offer discounts or promotions to customers who book early or who book for longer stays.Hotel can also offer incentives such as free parking or free breakfast to customers who book directly with them instead of through thirdparty websites.
#  This EDA involves following steps where in first step involves exploration and inspection over row data,and second in second step I have dealt with data impurities and cleaned the data by handling null values and dropping irrelevent data from the dataset.
#  This EDA is divided into following 3 analysis:Univariate analysis:Univariate analysis is the simplest of the three analyses where the data,you are analyzing is only one variable.Bivariate analysis:Bivariate analysis is where you are comparing more than two variables to study their relationships.Multivariate analysis:Multivariate analysis is similar to Bivariate analysis but you are comparing more than two variables.
#  The project concludes that by analyzing hotel booking data and understanding cancellations patterns hotes can take steps to reduce cancellations and reduce revenue.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
#  Have you ever wondered when best time of year to book a hotel room is? Or the optimal length of stay in the order to get the best daily rate?What if you wanted to predict whether or not a hotel was likely to receive a disproportionnately high of special reguests? This hotel booking dataset can help you explore those questions!This datset contains booking information for a city hotel and resort hotel and includes information,such as when the booking was made,length of stay,the numbers of adults,children and babies, and the numbers of avaliable parking spaces,among other things.Allpersonally identifying information has been removed from the data.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The project aimes to gain interesting insight into  customer's behavior when booking a hotel.The demand for different segment of customer may differ and forecasting become harder as it may requires model for different segment. These insight can guide hotels to adjust their customer strategies and make preparation for unknown.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as f
from plotly.colors import n_colors
from plotly.subplots import make_subplots
# Minmax scaler
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualisation data
# %matplotlib inline
import seaborn as sns
import plotly.express as px
from numpy.ma.core import absolute

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import files

# %%
hb_df=pd.read_csv('/content/Hotel Bookings.csv')

# %%
hb_df.shape

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
hb_df

# %%
#looking first 5 head of data set
hb_df.head()

# %%
#looking first 5 tail of data set
hb_df.tail()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f'Number of rows : {len(hb_df.axes[0])}')
print(f'Number of rows : {len(hb_df.axes[1])}')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hb_df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
hb_df.duplicated().sum()

# %%
# dropping duplicate value

hb_df.drop_duplicates(inplace = True)

# %%
hb_df.shape

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
hb_df.isnull().sum()

# %%
# Visualizing the missing values

plt.figure(figsize=(20,8))
sns.heatmap(hb_df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Mising Date'})
plt.title('missing value', fontsize=18)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
#  We can see that there are total four column with missing/null values:company,agent,country,children
#  1. In children column,I will replace null values with 0 assuming that customer did not have any children
#  2. Column country has null values.I will replace null values in this column with 'Othera'assuming customer's country was not mentioned while bookings.
#  3. In company and agent column it might be a case when customers did not book hotel through them so these columnsmight have null values in it. As these 2  columns have numeric data in it, I will replace them with0.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hb_df.columns

# %%
# Dataset Describe
hb_df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. **Hotel** : (Resort hotel or City Hotel)
# 2. **is_canceled** : Value indicating if the booking was canceled(1)or
# not (0)
# 3.**lead_time **: *Number of days that elapsed between the entering data of booking into the PMS and the arrival date*
# 4. **arrival_date_year** : Year of arrival date
# 5. **arrival_date_month** : Month of arrival date
# 6. **arrival_date_week_number** : week number of year for arrival date
# 7. **arrival_date_day_of_month** : Day of arrival date
# 8. **stay_in_weekend_nights** : Number of weekened nights(Saturday or Sunday)the guest or booked to stay at the hotel
# 9. **stays_in_week_nights** : Number of week nights(Monday to Friday)the guest stayed or booked to stay at the hotel
# 10. **adults** : Number of adults
# 11. **children** : Number of children
# 12. ** babies **: Number of babies
# 13. **meal**:Type of meal booked.Categories are presented in standard hositality meal packages
# 14. **country**:Country of origin,market_segment:Market segment designation,In categories, the term "TA"means"Travel Agent" and "To"means"Tour Operators"
# 15. **distribution_channel**:Booking distribution channel.The term"TA"means "Travel Agent" and "TO" means "Tour Operators"
# 16. **is_repeated**:Value indicating if the booking name was from a repeated guest(1)or not(0)
# 17. **previous_cancellations**:Number of previous booking that were cancelled by the customer prior to the current booking
# 18. **previous_booking_not_canceled**:Numbers of previous booking not cancelled  by the customerprior to the current booking
# 19. **reseved_room_type**:Code of room type reseved.Code is presented instead of designation for anonymity resons.
# 20. **assigned_room type**:Code for the type of room assigned to the booking
# 21. **booking_changes**:Number of change made to the booking from the moment the booking was entered on the PMS until the moment of chec-in or cancellation
# 22. **deposit_type**:indication on if the customer made  a deposit to guarantee the booking
# 23. **agent**:ID of the travel agency that made the booking
# 24. **compay**:ID of the compay that made the booking or responsible for paying the booking
# 25. **days_in_waiting_list**:Numbers of days the booking was in the waiting list before it wasconfirmed to the customer
# 26. **customer_type**:Type of booking,assuming one of four categories
# 27. **adr**:Average daily rate as define by diving the sum of all booking transaction by the total number of staying nights
# 28. **required_car_parking_spaces**:Number of car parking spaces required by the customer
# 29. **total_of_special_requests**:Number of special reuests made by the customer(e.g twin bed or high floor)
# 30. **reservation_status**:Reservation  last status,assuming one of three categories
# 31. **canceled**:Booking was cancelled by the customer
# 32. **checkout**-customer has checked in but already departed
# 33. **no show**-customer did not check in and did inform the hotel of the reson why
# 34. **reservation_status_date**-Date at which the last status was set.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
pd.Series({col:hb_df[col].unique() for col in hb_df})

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# creating a dublicate of the original dataset before making any change in it
hb_df1 = hb_df.copy()

# %%
hb_df1.columns

# %%
# Replacing null values in children column with 0 assuming that family had 0 children
# replacing null values in company and agent column with o assuming those rooms were booked without company/agent

hb_df1['children'].fillna(0, inplace = True)
hb_df1['company'].fillna(0, inplace = True)
hb_df1['agent'].fillna(0, inplace = True)

# replacing null values in country column as others
hb_df1['country'].fillna('others', inplace = True)

# %%
# checking for null values after replace them
hb_df1.isnull().sum()

# %%
# Dropping the 'compay' column as it contains  a lot of null values in camparison to other column

hb_df1.drop(['company'], axis =1 , inplace = True)       # dropping the values vertically at axis

# %%
#dropping rows where no adults, children and babies are available because no bookings
no_guest=hb_df1[hb_df1['adults']+hb_df1['babies'] + hb_df1['children']==0]
hb_df1.drop(no_guest.index, inplace=True)

# %%
# adding some new column to make our data analysis ready
hb_df1['total_people'] = hb_df1['adults'] + hb_df1['babies'] + hb_df1['children']

hb_df1['total_stay'] = hb_df1['stays_in_weekend_nights'] + hb_df1['stays_in_week_nights']

# %%
# having a final look to check if our dataset is ready to analyse
hb_df1.head()

# %%
hb_df1.tail()

# %%
# checking the final shape of the dataset
print(f'final shape of the dataset is {hb_df1.shape}')

# %%
# checking the unique values which is to be analysed
pd.Series({col:hb_df1[col].unique() for col in hb_df1})

# %% [markdown]
# We can see that we have deal with all the null values and added some new columns and now our dataset is ready to analysed

# %% [markdown]
# ---

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Created a copy of the dataset before doing any manupulation then filled missing values with 0 in children,compay and agent columns as those columns had numerical values and in column country filled missing values with others after dealing with missing values.I droped the country column as this had 96% missing values and was of no use in our analysis.In next step I create 2 new columns named'total_people' and 'total_stay' for the futher analysis.In total people column I addded all the babies,children and adults.similarly in second new column I added weekend stay and week stay column
#
# After doing all the manipulation I checked new manipulated dataset to check if this is ready to analysed
#
# After maniputating the dataset these were insight i found
#
# 1. There are two type of hotel which guest could back so I can find which type of hotel was booked most
# 2. These of different type of guest and they come from different contries
# 3. Guests choose different foods fromm food menu.
# 4. Guests can book hotel directly or thourgh different channels that are available
# 5. Guests can cancel there booking and there are repeated guests also
# 6. Guests can choose room of their liking while booking
# 7. There is column avaliable in the dataset named'adr'which could be used to analysed hotel performance on the basis of revenue.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# **Which type of hotel preffered by the guests**

# %%
# Chart - 1 visualization code
# storing unique hotel names in a variables
hotel_name = hb_df1['hotel'].unique()

#checking the number of unique booking in each hotel type
unique_booking = hb_df1.hotel.value_counts()

#creating a donut chart using plotly.express
fig1 = px.pie(names = hotel_name, values = unique_booking, hole = 0.5, color = hotel_name,
              color_discrete_map={
                  'Resort Hotel': 'teal' , 'City Hotel' : 'nude' })

# Giving it a title and updating the text info
fig1.update_traces(textinfo = 'percent + value')
fig1.update_layout(title_text = 'Hotel Booking Percentage, title_x = 0.5')

# setting the legend at center
fig1.update_layout(legend=dict(
    orientation = 'h',
    yanchor = 'bottom',
    xanchor = 'center',
    x = 0.5
))

# display the figure
fig1.show()

# %%
# count Hotel
hotel_count = hb_df1.hotel.value_counts()

# plotting values in a simple pie chart
hotel_count.plot.pie(figsize=(9,7), autopct='%1.2f%%', shadow=True, fontsize=15, startangle=50)

#setting the title
plt.title('Hotel Booking Percentage')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used Donut chart here because it is used to show the proportions of categorical data.with the size of each piece representing the proportion of each category

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I found out that guests prefer Resort Hotel over City Hotel

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight is useful for the stackeholder to check hotel is performing best and they can invest more capitals in that. There is no such negative growth but stackeholder can focus more on city Hotel to get more booking the overall revenue.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# **what is percentage of booking cancellation?**

# %%
# Chart - 2 visualization code
# Extracting and shorting unique values of hotel cancelation
cancelled_hotel = hb_df1.is_canceled.value_counts()
# Creating a pie chart
cancelled_hotel.plot.pie(figsize=(9,7), explode=(0.05,0.05), autopct='%1.2f%%', shadow=True, fontsize=15,startangle=50)

# Giving our pie chart a title
plt.title('Percentage of Hotel Cancellation and Non Cancellation')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I had to show a part to a whole relationship and percentage of both the values and here pie chart was a good options to show segmented values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see that around 72.48% booking are not cancelled by guests but around 27.52% booking are cancelled by guests

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This might will help stackholders in comparing the cancellation and non-cancellation of booking.With the help of this insight stackholders can offer rescheduling the booking instead of cancellation and set a flexible cancellation policy to reduce booking cancellation

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# counting each meal type
meal_count = hb_df1.meal.value_counts()

# Extracting each meal type and storing in a variable
meal_name = hb_df1['meal'].unique()

# Creating a dataset of each meal type and count
meal_df = pd.DataFrame(zip(meal_name,meal_count), columns = ['meal name', 'meal count'])

# visualization the values on a bar chart
plt.figure(figsize=(15,5))
g = sns.barplot(data=meal_df, x ='meal name', y ='meal count')
g.set_xticklabels(meal_df['meal name'])
plt.title('mostpreffered meal type', fontsize=25)
plt.show()

# %% [markdown]
# **meal type  variables descriptions**
#
# **BB**-(Bed and Breakfast)
#
# **HB**-(Half Board)
#
# **FB**-(Self Catering)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# There are four values to compare and Bar graphs are used to compare things between different groups that is why I used this chart

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# After visualization the above chart we can see that BB-(Bed and breakfast) is the most preffered meal type by guests

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,from the gained insight above now stackholders know that BB-(Bed and Breakfast)is most prefered meal type so they can arrange raw material for this meal in advance and deliver the meal without and delay

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# plotting with countplot

plt.figure(figsize = (10,4))
sns.countplot(x=hb_df1['arrival_date_year'],hue=hb_df1['hotel'])
plt.title("Number of bookings across year", fontsize = 25)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar graphs are used to compare things between different groups that is why i used this chart

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above insight I found out that hotel was booked most times in year 2016.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Above insight shows that number of booking was declined after year 2016.stackeholder can now what went wrong 2016 and fix that problem to increase the number of bookings. one way to do this is ask for feedbacks from guests and have a meeting with old employes who else were serving in the year 2016

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# **Which month has the most booking in each hotel?**

# %%
# Chart - 5 visualization code
plt.figure(figsize=(15,5))
sns.countplot(x=hb_df1['arrival_date_month'],hue=hb_df1['hotel'])
plt.title("Number of booking across month", fontsize = 25)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I had to compare values across the month and for that bar chart was one of the best choice

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Above insight shows that august and july were 2 most busy months in compare to others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There is negative insight but hotel can use this insight to arrange eveything in advance and welcome their guests in the best way possible and hotel can also run some promotional offer in these 2 months to attract more guests

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# counting number of guest from various countries and changing column names
country_df = hb_df1['country'].value_counts().reset_index().rename(columns={'index': 'country','country':'guests count'})[:10]

# visualization the values on a bar chart
# setting the graph size
plt.figure(figsize=(15,4))
sns.barplot(x=country_df['country'], y=country_df['guests count'])
plt.title('Number of guests from each country', fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I compared different values that's why I used barchart

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart I found out that most guests come from portugal.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There is no negative insight. After knowing that most of the guests of the guests come from portugal hotels can add more portugal cousiness and in their menu to make guests order more food

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# **Which distribution channel is most used in booking?**

# %%
# Chart - 7 visualization code
# creating a dataset of distribution channel name and count
dist_df = hb_df1['distribution_channel'].value_counts().reset_index()

# Renaming the columns to appropiate names
dist_df = dist_df.rename(columns={'index':'channel name', 'distribution_channel':'channel count'})

# Creating a explode data
my_explode = (0.05,0.05,0.05,0.05,0.5)

# adding percentage columns to the distribution_channel_df
dist_df['percentage']=round(dist_df['channel count']*100/hb_df1.shape[0],1)

# deciding the figure size
plt.figure(figsize=(15,6))

# plotting the chart values
plt.pie(dist_df['channel count'], labels=None, explode = my_explode, startangle = 50)

# adding legends with percentage using list comprehension
labels  = [f'{1}, {s}%' for l, s in zip(dist_df['channel name'].value_counts().index.tolist(), dist_df['percentage'].values.tolist())]
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
# show the chart
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is one of the best chart to visualize categorical data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above insights it is clear that TA/TO(travel agent/tour operators)is most used distribution channel by guests

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There is no negative insight.Hotels can run promotional offers to motivate other channels to contributed more in booking

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# **Which type of room id most preffered by guests ?**

# %%
# Chart - 8 visualization code
# Setting the figure size
plt.figure(figsize=(15,5))

# plotting the values in chart
sns.countplot(x=hb_df1['reserved_room_type'],order=hb_df1['reserved_room_type'].value_counts().index)

# setting the title
plt.title('Preffered Room Type by Guests', fontsize = 20)

# show the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot shows categorical data as rectangular bars with the height of bars proportional to the value they represent.It is often used to  compare between values of different categorices in the data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By observing the above chart can understand that the room type A most preffered (almost 35000)by the guests while booking the hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As it is clear that room type A is most used. hotel should increase the number of A typr room to maximize the revenue

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# **Which room type is most assigned ?**

# %%
# Chart - 9 visualization code
# Setting the figure size
plt.figure(figsize=(15,5))

# plotting the values
sns.countplot(x=hb_df1['assigned_room_type'], order = hb_df1['assigned_room_type'].value_counts().index)

# setting the title
plt.title('Assigned Room Type to Guests', fontsize = 20)
# show the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot shows categorical data as rectangular bars with the height of bars proportional to the value the represent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart it is clear that room type A is most assigned to guests

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In the 8th chart that around 55,000 guests preffered room typeA but 45,000 people were assigned A type room.This could be reason to cancel the bookings.Hotel could increase A type room to decrease cancellation

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# **Top 5 Agents in terms of most bookings ?**

# %%
# Chart - 10 visualization code
 # creating a data set by grouping by agent column and it's count
agents = hb_df1.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count':'Booking Count'}
                                                                                ).sort_values(by = 'Booking Count', ascending = False)

# Extracting top 5 agent by booking count
top_5  = agents[:5]

# Explosion
explode = (0.02,0.02,0.02,0.02,0.02)

# colours
colors = ("orange", "cyan", "brown", "indigo", "beige")

# Wedge properties
wp = {'linewidth' : 1, 'edgecolor' : "green"}

# creating autocpt arguments
def func(pct, allvalues):
  absolute = int(pct / 100.*np.sum(allvalues))
  return "{:.1f}%\n({:d} g)".format(pct, absolute)

# plotting values
fig, ax = plt.subplots(figsize=(15, 7))
wedges, texts, autotexts = ax.pie(top_5['Booking Count'],
                                  autopct = lambda pct: func(pct, top_5['Booking Count']),
                                  explode = explode,
                                  shadow = False,
                                  colors = colors,
                                  startangle = 50,
                                  wedgeprops = wp)

# adding the legend
ax.legend(wedges, top_5['agent'],
          title ="agents",
          loc ="upper left",
          bbox_to_anchor =(1, 0, 0.5, 1))

plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Top 5 agent in terms of Booking", fontsize = 17)

# Show chart
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that agent number 9 has made the most number of bookings followed by agent number 240,0,14 and7.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotel can offer them bonus for their incredible work and to motivate them.This will help to increase the revenue.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# **What is the percentages of repeated guests ?**

# %%
# Chart - 11 visualization code
# creating a variable containing guests with their repeated counts
rep_guests = hb_df1['is_repeated_guest'].value_counts()

# plotting the value in a pie chart
rep_guests.plot.pie(autopct='%1.2f%%', explode=(0.00,0.09), figsize=(15,6), shadow=False)

# setting the title
plt.title('Percentage of Repeated Guests', fontsize=20)

# setting the chart in centre
plt.axis('equal')

# show chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above insight we can se that 3.86% guests are repeated guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can see that number of repeated guests is very low and it shows negative growth of the hotel.Hotel can offer loyality discount to their guests to increase repeated gursts.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# **Which customers type has the most booking ?**

# %%
# Chart - 12 visualization code
cust_type = hb_df1['customer_type'].value_counts()

# plotting the values in a line chart
cust_type.plot(figsize=(15,5))

# setting the x label, y label and title
plt.xlabel('Count', fontsize=8)
plt.ylabel('Customer Type', fontsize=10)
plt.title('Customer Type and their booking count', fontsize=20)

# show the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line graphs are used to track changes over different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that transient customer type has the most number of bookings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotel can run promotional offers to increase the number of booking over other categories,such as hotel could offer discounts for guests.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# **Which market segment has the most booking ?**

# %%
# Chart - 13 visualization code
plt.figure(figsize=(15,5))
sns.countplot(x=hb_df1['market_segment'], order = hb_df1['market_segment'].value_counts().index)
plt.title('Market segment sahre in booking', fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar shows categorical data as rectangular bars with the height of bars proportional to the value they represet.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Above insight shows that online TA (Travel Agent) has the most bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There is no negative growth.Hotel should come up with some great idea to increase sahre among other market segments to increase the revenue.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %% [markdown]
# **Which deposite type is most preffered ?**

# %%
# Correlation Heatmap visualization code
# counting each deposite type
deposite = hb_df1['deposit_type'].value_counts().index

# setting the chart size
plt.figure(figsize=(8,4))

# plotting the value
sns.countplot(x=hb_df1['deposit_type'], order= deposite)
plt.title('Most used deposite type')
plt.show()

# %% [markdown]
# # Bivariate and multivariate analysis

# %%
 # chart - 15 visualization code
 # creating a not cancelled dataframe
 not_cancelled_df = hb_df1[hb_df1['is_canceled'] == 0]
 # Creating a hotel stay dataframe
 hotel_stay = not_cancelled_df[not_cancelled_df['total_stay'] <= 15]

 # setting plot size and potting barchart
 plt.figure(figsize = (15,5))
 sns.countplot(x = hotel_stay['total_stay'], hue = hotel_stay['hotel'])

 # Adding the label of the chart
 plt.title('Total number of stay i each hotel', fontsize = 20)
 plt.xlabel('Total stay')
 plt.ylabel(" Count of days")
 plt.show()

# %% [markdown]
# # WHICH HOTEL MOST REVENUE

# %%
# counting the revnue for each hotel type using groupby function
most_rev = hb_df1.groupby('hotel')['adr'].count()

# plotting the value in a pie chart
most_rev.plot.pie(autopct='%1.2f%%',figsize=(15,5))

# setting the title
plt.title('Percentage of daily revenue by each hotel type', fontsize=20)
plt.axis('equal')

# show chart
plt.show()

# %%
# Grouping by hotel and taking the mean of days in waiting list
waiting_time_df = hb_df1.groupby('hotel')['days_in_waiting_list'].mean().reset_index()
# watinf time df

# setting the plot size
plt.figure(figsize=(8,4))

# plotting the bar chart
sns.barplot(x=waiting_time_df['hotel'], y=waiting_time_df['days_in_waiting_list'])

# setting the labels
plt.xlabel('Hotel type', fontsize=12)
plt.ylabel('Waiting time', fontsize=12)
plt.title("waiting time for each hotel type", fontsize=20)

# show chart
plt.show()

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(hb_df1)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
